# %% [markdown]
# # RAG Demo: ATT&CK + Sigma (Mini)
# This notebook ingests tiny knowledge snippets, builds an in-memory vector index with Qdrant, and retrieves top-k passages to prepend to your model prompts.

# %% [markdown]
# ## 1) Install deps (Colab/Kaggle/local)

# %%
# !pip -q install "sentence-transformers>=2.7.0" qdrant-client

# %% [markdown]
# ## 2) Ingest & Search

# %%
# !python scripts/rag_ingest.py

# %% [markdown]
# ## 3) Use retrieved context to augment prompts
# In your training/eval loops, prepend retrieved text to the user alert before generation. Keep total prompt under your context window (e.g., 2k tokens).
